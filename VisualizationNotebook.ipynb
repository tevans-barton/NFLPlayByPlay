# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
nfl_data = pd.read_csv('cleaned_nfl_data.csv')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
nfl_data = nfl_data.drop('Unnamed: 0', axis = 1)

# %%
temp = nfl_data[['GameID', 'HomeScore', 'AwayScore', 'HomeTeam', 'AwayTeam']].groupby('GameID').aggregate(max).reset_index()
temp
# Out:
#           GameID  HomeScore  AwayScore HomeTeam AwayTeam
# 0     2009091000       13.0       10.0      PIT      TEN
# 1     2009091300       19.0        7.0      ATL      MIA
# 2     2009091301       38.0       23.0      BAL       KC
# 3     2009091302       10.0       36.0      CAR      PHI
# 4     2009091303        7.0       12.0      CIN      DEN
# ...          ...        ...        ...      ...      ...
# 2299  2017123111       15.0        3.0      TEN      JAX
# 2300  2017123112       17.0       26.0      DEN       KC
# 2301  2017123113       30.0       10.0      LAC      OAK
# 2302  2017123114       13.0       34.0       LA       SF
# 2303  2017123115       24.0       26.0      SEA      ARI
#
# [2304 rows x 5 columns]

# %%
winners = {}
for x in range(len(temp)):
    if temp['HomeScore'][x] > temp['AwayScore'][x]:
        winners[temp['GameID'][x]] = temp['HomeTeam'][x]
    elif temp['HomeScore'][x] < temp['AwayScore'][x]:
        winners[temp['GameID'][x]] = temp['AwayTeam'][x]
    else:
        winners[temp['GameID'][x]] = 'TIE'

# %%
nfl_data['Winner'] = [winners[nfl_data['GameID'][x]] for x in range(len(nfl_data))]
nfl_data
# Out:
#             GameID  Drive  qtr  down  TimeSecs SideofField  yrdline100  \
# 0       2009091000      1    1   NaN    3600.0         TEN        30.0
# 1       2009091000      1    1   1.0    3593.0         PIT        58.0
# 2       2009091000      1    1   2.0    3556.0         PIT        53.0
# 3       2009091000      1    1   3.0    3515.0         PIT        56.0
# 4       2009091000      1    1   4.0    3507.0         PIT        56.0
# ...            ...    ...  ...   ...       ...         ...         ...
# 407683  2017123101     29    4   NaN      28.0         BAL        32.0
# 407684  2017123101     29    4   3.0      28.0         BAL        77.0
# 407685  2017123101     29    4   4.0      24.0         BAL        77.0
# 407686  2017123101     30    4   1.0      14.0         BAL        36.0
# 407687  2017123101     30    4   NaN       0.0         BAL        36.0
#
#         ydstogo  ydsnet  GoalToGo  FirstDown posteam DefensiveTeam  \
# ...

# %%
nfl_data.to_csv('cleaned_nfl_data(v2).csv')
